# %% [markdown]
# # Tick Strategy
# ### Team: Blue Horseshoe

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# load our helper functios
import simtools as st
import ticktest as tk
from getstock import *
from simtools import *

matplotlib.rcParams[ 'figure.figsize' ] = ( 16, 9 )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 0. Load TAQ Data
#
# We'll assume we have already done some cleaning by using our Tick Data Setup or similar code

# %%
# set up some variables
# NOTE: tickfile is a merged TAQ file!!!
tickfile = 'APPL-TAQ-Sep03.zip'
#test_day = '09/03/19'
taq = pd.read_pickle(tickfile)

# %%
len(taq)
# Out:
# 2606652

# %%
taq.iloc[-200000:-100000]

# filter on date
#day = taq[test_day]
# Out:
#                               exch  bid_px  bid_size  ask_px  ask_size  \
# 2019-09-03 15:39:51.489833317    N  205.78       2.0  205.80       4.0
# 2019-09-03 15:39:51.489858302    N  205.78       2.0  205.80       3.0
# 2019-09-03 15:39:51.489869871    Y  205.70       1.0  205.87       1.0
# 2019-09-03 15:39:51.489878344    Q  205.78       6.0  205.79       2.0
# 2019-09-03 15:39:51.489992188    C  205.78       1.0  217.14       1.0
# 2019-09-03 15:39:51.490069360    N  205.78       3.0  205.80       3.0
# 2019-09-03 15:39:51.490084536    N  205.78       4.0  205.80       3.0
# 2019-09-03 15:39:51.490085384    P  205.75       3.0  205.80       2.0
# 2019-09-03 15:39:51.490123296    Y  205.70       1.0  210.00       1.0
# 2019-09-03 15:39:51.490127935    N  205.78       5.0  205.80       3.0
# 2019-09-03 15:39:51.490162778    N  205.78       6.0  205.80       3.0
# 2019-09-03 15:39:51.490207194    Y  205.71       1.0  210.00       1.0
# 2019-09-03 15:39:51.490434419    V  205.77       1.0  205.80       1.0
# 2019-09-03 15:39:51.490452167    V  205.77       1.0  208.00       1.0
# 2019-09-03 15:39:51.491278438    V  205.76       1.0  208.00       1.0
# 2019-09-03 15:39:51.499282744    Q  205.78       5.0  205.79       2.0
# 2019-09-03 15:39:51.499297912    K  205.73       1.0  205.80       1.0
# 2019-09-03 15:39:51.499662075    N  205.78       5.0  205.80       3.0
# 2019-09-03 15:39:51.499672087    N  205.78       4.0  205.80       3.0
# 2019-09-03 15:39:51.499682008    N  205.78       3.0  205.80       3.0
# 2019-09-03 15:39:51.502996614  NaN     NaN       NaN     NaN       NaN
# 2019-09-03 15:39:51.502997917    Q  205.78       5.0  205.79       1.0
# 2019-09-03 15:39:51.502999634  NaN     NaN       NaN     NaN       NaN
# 2019-09-03 15:39:51.503019282    Q  205.78       6.0  205.79       1.0
# 2019-09-03 15:39:51.503069977    Q  205.78       5.0  205.79       1.0
# 2019-09-03 15:39:51.503103869    B  205.62       1.0  205.83       1.0
# 2019-09-03 15:39:51.503106878    X  205.75       1.0  205.83       1.0
# 2019-09-03 15:39:51.503350235    K  205.78       1.0  205.80       1.0
# 2019-09-03 15:39:51.505732898    K  205.73       1.0  205.80       1.0
# 2019-09-03 15:39:51.519705188    Z  205.78       2.0  205.80       3.0
# ...                            ...     ...       ...     ...       ...
# 2019-09-03 15:50:52.079388074    N  205.92       2.0  205.94      13.0
# 2019-09-03 15:50:52.079399250    N  205.92       2.0  205.94      14.0
# 2019-09-03 15:39:51.491278438       R  32296225.0         0.0        NaN
# 2019-09-03 15:39:51.499282744       R  32296227.0         2.0        NaN
# 2019-09-03 15:39:51.499297912       R  32296228.0         0.0        NaN
# 2019-09-03 15:39:51.499662075       R  32296229.0         2.0        NaN
# 2019-09-03 15:39:51.499672087       R  32296230.0         0.0        NaN
# 2019-09-03 15:39:51.499682008       R  32296231.0         0.0        NaN
# 2019-09-03 15:39:51.502996614     NaN         NaN         NaN        NaN
# 2019-09-03 15:39:51.502997917       R  32296233.0         4.0        NaN
# 2019-09-03 15:39:51.502999634     NaN         NaN         NaN        NaN
# 2019-09-03 15:39:51.503019282       R  32296234.0         4.0        NaN
# 2019-09-03 15:39:51.503069977       R  32296235.0         4.0        NaN
# 2019-09-03 15:39:51.503103869       R  32296236.0         0.0        NaN
# 2019-09-03 15:39:51.503106878       R  32296237.0         0.0        NaN
# 2019-09-03 15:39:51.503350235       R  32296238.0         0.0        NaN
# 2019-09-03 15:39:51.505732898       R  32296251.0         0.0        NaN
# 2019-09-03 15:39:51.519705188       R  32296279.0         0.0        NaN
# ...                               ...         ...         ...        ...
# 2019-09-03 15:50:52.079388074       R  33431661.0         0.0        NaN
# 2019-09-03 15:50:52.079399250       R  33431662.0         0.0        NaN
# 2019-09-03 15:50:52.079427358       R  33431663.0         0.0        NaN
# 2019-09-03 15:50:52.079433910       R  33431664.0         0.0        NaN
# 2019-09-03 15:50:52.079468583       R  33431665.0         0.0        NaN
# 2019-09-03 15:50:52.079471422       R  33431666.0         0.0        NaN
# 2019-09-03 15:50:52.079475484       R  33431667.0         2.0        NaN
# 2019-09-03 15:50:52.079479163       R  33431668.0         2.0        NaN
# 2019-09-03 15:50:52.079483371       R  33431669.0         0.0        NaN
# 2019-09-03 15:50:52.079487107       R  33431670.0         0.0        NaN
# 2019-09-03 15:50:52.079527316       R  33431671.0         0.0        NaN
# 2019-09-03 15:50:52.079534723       R  33431672.0         4.0        NaN
# 2019-09-03 15:50:52.079601848       R  33431673.0         0.0        NaN
# 2019-09-03 15:50:52.079628401       R  33431674.0         0.0        NaN
# 2019-09-03 15:50:52.079636220       R  33431675.0         0.0        NaN
# 2019-09-03 15:50:52.079639532       R  33431676.0         0.0        NaN
# 2019-09-03 15:50:52.079659221       R  33431677.0         0.0        NaN
# 2019-09-03 15:50:52.080239913       R  33431678.0         0.0        NaN
# 2019-09-03 15:50:52.080251231       R  33431679.0         0.0        NaN
# 2019-09-03 15:50:52.080263587       R  33431680.0         0.0        NaN
# 2019-09-03 15:50:52.080339181       R  33431681.0         0.0        NaN
# 2019-09-03 15:50:52.080907796       R  33431684.0         0.0        NaN
# 2019-09-03 15:50:52.081242498       R  33431686.0         0.0        NaN
# 2019-09-03 15:50:52.081386853       R  33431687.0         0.0        NaN
# 2019-09-03 15:50:52.081926696       R  33431688.0         0.0        NaN
# 2019-09-03 15:50:52.109211966       R  33431741.0         0.0        NaN
# 2019-09-03 15:50:52.109275673       R  33431744.0         4.0        NaN
# 2019-09-03 15:50:52.109283747       R  33431745.0         2.0        NaN
# 2019-09-03 15:50:52.109598848       R  33431746.0         0.0        NaN
# 2019-09-03 15:50:52.109662228       R  33431747.0         2.0        NaN
#
#                               qu_source symbol  suffix_x  suffix_y  \
# 2019-09-03 15:39:51.489833317         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.489858302         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.489869871         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.489878344         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.489992188         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.490069360         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.490084536         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.490085384         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.490123296         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.490127935         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.490162778         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.490207194         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.490434419         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.490452167         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.491278438         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.499282744         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.499297912         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.499662075         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.499672087         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.499682008         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.502996614       NaN   AAPL       NaN       NaN
# 2019-09-03 15:39:51.502997917         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.502999634       NaN   AAPL       NaN       NaN
# 2019-09-03 15:39:51.503019282         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.503069977         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.503103869         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.503106878         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.503350235         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.505732898         N   AAPL       NaN       NaN
# 2019-09-03 15:39:51.519705188         N   AAPL       NaN       NaN
# ...                                 ...    ...       ...       ...
# 2019-09-03 15:50:52.079388074         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079399250         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079427358         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079433910         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079468583         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079471422         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079475484         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079479163         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079483371         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079487107         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079527316         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079534723         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079601848         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079628401         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079636220         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079639532         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.079659221         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.080239913         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.080251231         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.080263587         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.080339181         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.080907796         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.081242498         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.081386853         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.081926696         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.109211966         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.109275673         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.109283747         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.109598848         N   AAPL       NaN       NaN
# 2019-09-03 15:50:52.109662228         N   AAPL       NaN       NaN
#
#                                trade_size  trade_px
# 2019-09-03 15:39:51.489833317         NaN       NaN
# 2019-09-03 15:39:51.489858302         NaN       NaN
# 2019-09-03 15:39:51.489869871         NaN       NaN
# 2019-09-03 15:39:51.489878344         NaN       NaN
# 2019-09-03 15:39:51.489992188         NaN       NaN
# 2019-09-03 15:39:51.490069360         NaN       NaN
# 2019-09-03 15:39:51.490084536         NaN       NaN
# 2019-09-03 15:39:51.490085384         NaN       NaN
# 2019-09-03 15:39:51.490123296         NaN       NaN
# 2019-09-03 15:39:51.490127935         NaN       NaN
# 2019-09-03 15:39:51.490162778         NaN       NaN
# 2019-09-03 15:39:51.490207194         NaN       NaN
# 2019-09-03 15:39:51.490434419         NaN       NaN
# 2019-09-03 15:39:51.490452167         NaN       NaN
# 2019-09-03 15:39:51.491278438         NaN       NaN
# 2019-09-03 15:39:51.499282744         NaN       NaN
# 2019-09-03 15:39:51.499297912         NaN       NaN
# 2019-09-03 15:39:51.499662075         NaN       NaN
# 2019-09-03 15:39:51.499672087         NaN       NaN
# 2019-09-03 15:39:51.499682008         NaN       NaN
# 2019-09-03 15:39:51.502996614        32.0    205.79
# 2019-09-03 15:39:51.502997917         NaN       NaN
# 2019-09-03 15:39:51.502999634        68.0    205.79
# 2019-09-03 15:39:51.503019282         NaN       NaN
# 2019-09-03 15:39:51.503069977         NaN       NaN
# 2019-09-03 15:39:51.503103869         NaN       NaN
# 2019-09-03 15:39:51.503106878         NaN       NaN
# 2019-09-03 15:39:51.503350235         NaN       NaN
# 2019-09-03 15:39:51.505732898         NaN       NaN
# 2019-09-03 15:39:51.519705188         NaN       NaN
# ...                                   ...       ...
# 2019-09-03 15:50:52.079388074         NaN       NaN
# 2019-09-03 15:50:52.079399250         NaN       NaN
# 2019-09-03 15:50:52.079427358         NaN       NaN
# 2019-09-03 15:50:52.079433910         NaN       NaN
# 2019-09-03 15:50:52.079468583         NaN       NaN
# 2019-09-03 15:50:52.079471422         NaN       NaN
# 2019-09-03 15:50:52.079475484         NaN       NaN
# 2019-09-03 15:50:52.079479163         NaN       NaN
# 2019-09-03 15:50:52.079483371         NaN       NaN
# 2019-09-03 15:50:52.079487107         NaN       NaN
# 2019-09-03 15:50:52.079527316         NaN       NaN
# 2019-09-03 15:50:52.079534723         NaN       NaN
# 2019-09-03 15:50:52.079601848         NaN       NaN
# 2019-09-03 15:50:52.079628401         NaN       NaN
# 2019-09-03 15:50:52.079636220         NaN       NaN
# 2019-09-03 15:50:52.079639532         NaN       NaN
# 2019-09-03 15:50:52.079659221         NaN       NaN
# 2019-09-03 15:50:52.080239913         NaN       NaN
# 2019-09-03 15:50:52.080251231         NaN       NaN
# 2019-09-03 15:50:52.080263587         NaN       NaN
# 2019-09-03 15:50:52.080339181         NaN       NaN
# 2019-09-03 15:50:52.080907796         NaN       NaN
# 2019-09-03 15:50:52.081242498         NaN       NaN
# 2019-09-03 15:50:52.081386853         NaN       NaN
# 2019-09-03 15:50:52.081926696         NaN       NaN
# 2019-09-03 15:50:52.109211966         NaN       NaN
# 2019-09-03 15:50:52.109275673         NaN       NaN
# 2019-09-03 15:50:52.109283747         NaN       NaN
# 2019-09-03 15:50:52.109598848         NaN       NaN
# 2019-09-03 15:50:52.109662228         NaN       NaN
#
# [100000 rows x 15 columns]

# %% [markdown]
# ## 1. Implement the Tick Strategy

# %%
import ticktest as tk

# %%
# without the tick signal...
results1 = tk.algo_loop( taq.iloc[100000:150000] )
# Out:
# 2019-10-30 21:56:19:800019: Beginning Tick Strategy run
# 2019-10-30 21:56:19:800212: TODO: remove this message. Simply a test to see how closely you are reading this code
# Average stock spread for sample: 2.1180
# 2019-10-30 21:56:19:876067: starting main loop
# index 2019-09-03 09:38:16.241679667
# index 2019-09-03 09:38:16.241693606
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.38 206.35 206.89 206.38
# Agg b 206.89
# order_side,order_quantity,trade_price,last_price b 1 206.38 206.38
# position 1 unreal_pnl 0.00 real_pnl 0.00 ave_price 206.38
# index 2019-09-03 09:38:16.241741991
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.38 206.35 206.89 206.38
# Agg b 206.89
# order_side,order_quantity,trade_price,last_price b 1 206.38 206.38
# position 2 unreal_pnl 0.00 real_pnl 0.00 ave_price 206.38
# index 2019-09-03 09:38:16.242107846
# index 2019-09-03 09:38:16.858500175
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.91 206.38
# Agg b 206.91
# order_side,order_quantity,trade_price,last_price b 1 206.4 206.38
# position 3 unreal_pnl -0.02 real_pnl 0.00 ave_price 206.39
# index 2019-09-03 09:38:16.858990497
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.81 206.37
# index 2019-09-03 09:38:16.858997451
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.72 206.37
# index 2019-09-03 09:38:16.859137337
# index 2019-09-03 09:38:17.244698778
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.73 206.38
# Agg b 206.73
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.38
# position 4 unreal_pnl -0.03 real_pnl 0.00 ave_price 206.39
# index 2019-09-03 09:38:17.292602798
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.65 206.36
# index 2019-09-03 09:38:17.292911152
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.57 206.35
# index 2019-09-03 09:38:17.292915834
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.5 206.35
# index 2019-09-03 09:38:17.292968177
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.44 206.35
# index 2019-09-03 09:38:17.293112852
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.38 206.35
# Pas s
# live order in
# live_order_price,last_price 206.38 206.35
# order side, success s 0
# index 2019-09-03 09:38:17.293145154
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.33 206.35
# Agg s 206.33
# order_side,order_quantity,trade_price,last_price s 1 206.36 206.35
# position 3 unreal_pnl -0.11 real_pnl -0.03 ave_price 206.39
# index 2019-09-03 09:38:17.293535447
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.39 206.36
# Pas b
# live order in
# live_order_price,last_price 206.39 206.3563
# order side, success b 1
# order_side,order_quantity,live_order_price,last_price b 1 206.39 206.3563
# position 4 unreal_pnl -0.13 real_pnl -0.03 ave_price 206.39
# index 2019-09-03 09:38:17.311745652
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.33 206.3563
# Agg s 206.33
# order_side,order_quantity,trade_price,last_price s 1 206.36 206.3563
# position 3 unreal_pnl -0.10 real_pnl -0.06 ave_price 206.39
# index 2019-09-03 09:38:17.511901738
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.29 206.352
# Agg s 206.29
# order_side,order_quantity,trade_price,last_price s 1 206.36 206.352
# position 2 unreal_pnl -0.07 real_pnl -0.08 ave_price 206.39
# index 2019-09-03 09:38:17.596473049
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.25 206.34
# Agg s 206.25
# order_side,order_quantity,trade_price,last_price s 1 206.36 206.34
# position 1 unreal_pnl -0.05 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.658489041
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.31 206.35
# index 2019-09-03 09:38:17.694703453
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.37 206.37
# Pas b
# live order in
# live_order_price,last_price 206.37 206.37
# order side, success b 1
# order_side,order_quantity,live_order_price,last_price b 1 206.37 206.37
# position 2 unreal_pnl -0.02 real_pnl -0.11 ave_price 206.38
# index 2019-09-03 09:38:17.694812236
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.42 206.37
# Agg b 206.42
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.37
# position 3 unreal_pnl -0.04 real_pnl -0.11 ave_price 206.38
# index 2019-09-03 09:38:17.695099284
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.46 206.37
# Agg b 206.46
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.37
# position 4 unreal_pnl -0.06 real_pnl -0.11 ave_price 206.38
# index 2019-09-03 09:38:17.695330214
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.51 206.37
# Agg b 206.51
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.37
# position 5 unreal_pnl -0.08 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.695935408
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.54 206.37
# Agg b 206.54
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.37
# position 6 unreal_pnl -0.10 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.702094072
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.58 206.37
# Agg b 206.58
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.37
# position 7 unreal_pnl -0.12 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.754800668
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.61 206.38
# Agg b 206.61
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.38
# position 8 unreal_pnl -0.06 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.754815144
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.64 206.38
# Agg b 206.64
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.38
# position 9 unreal_pnl -0.07 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.755086275
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.66 206.39
# Agg b 206.66
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.39
# position 10 unreal_pnl 0.02 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.766912160
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.69 206.39
# Agg b 206.69
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.39
# position 11 unreal_pnl 0.02 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.766990678
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.39 206.36 206.71 206.4
# Agg b 206.71
# order_side,order_quantity,trade_price,last_price b 1 206.39 206.4
# position 12 unreal_pnl 0.14 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.766993281
# index 2019-09-03 09:38:17.767012172
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.74 206.4
# Agg b 206.74
# order_side,order_quantity,trade_price,last_price b 1 206.4 206.4
# position 13 unreal_pnl 0.14 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.767022635
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.75 206.4
# Agg b 206.75
# order_side,order_quantity,trade_price,last_price b 1 206.4 206.4
# position 14 unreal_pnl 0.14 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.798627826
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.77 206.415
# Agg b 206.77
# order_side,order_quantity,trade_price,last_price b 1 206.4 206.415
# position 15 unreal_pnl 0.37 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.812922256
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.68 206.37
# index 2019-09-03 09:38:17.822059828
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.7 206.41
# Agg b 206.7
# order_side,order_quantity,trade_price,last_price b 1 206.4 206.41
# position 16 unreal_pnl 0.30 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.871263948
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.62 206.4
# index 2019-09-03 09:38:17.880092228
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.55 206.4
# index 2019-09-03 09:38:17.880526047
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.4 206.37 206.48 206.39
# index 2019-09-03 09:38:17.974072551
# index 2019-09-03 09:38:17.974101708
# index 2019-09-03 09:38:17.981864396
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.55 206.41
# Agg b 206.55
# order_side,order_quantity,trade_price,last_price b 1 206.43 206.41
# position 17 unreal_pnl 0.28 real_pnl -0.11 ave_price 206.39
# index 2019-09-03 09:38:17.981876964
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.59 206.41
# Agg b 206.59
# order_side,order_quantity,trade_price,last_price b 1 206.43 206.41
# position 18 unreal_pnl 0.26 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:17.981951926
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.63 206.41
# Agg b 206.63
# order_side,order_quantity,trade_price,last_price b 1 206.43 206.41
# position 19 unreal_pnl 0.24 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:17.983169777
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.66 206.41
# Agg b 206.66
# order_side,order_quantity,trade_price,last_price b 1 206.43 206.41
# position 20 unreal_pnl 0.22 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:17.998446488
# index 2019-09-03 09:38:18.249906457
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.68 206.43
# Agg b 206.68
# order_side,order_quantity,trade_price,last_price b 1 206.43 206.43
# position 21 unreal_pnl 0.62 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:18.296386259
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.61 206.415
# index 2019-09-03 09:38:18.399877117
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.54 206.415
# index 2019-09-03 09:38:19.023429868
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.48 206.4
# index 2019-09-03 09:38:19.023455761
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.42 206.4
# Pas s
# live order in
# live_order_price,last_price 206.42 206.4
# order side, success s 0
# index 2019-09-03 09:38:19.023458705
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.37 206.4
# Agg s 206.37
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.4
# position 20 unreal_pnl -0.01 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:19.024019190
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.32 206.4
# Agg s 206.32
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.4
# position 19 unreal_pnl -0.01 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:19.676328780
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.28 206.38
# Agg s 206.28
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.38
# position 18 unreal_pnl -0.37 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:19.677720767
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.24 206.37
# Agg s 206.24
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 17 unreal_pnl -0.52 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:19.677725348
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.21 206.37
# Agg s 206.21
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 16 unreal_pnl -0.49 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:19.682617273
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.18 206.37
# Agg s 206.18
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 15 unreal_pnl -0.46 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:19.683235176
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.15 206.37
# Agg s 206.15
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 14 unreal_pnl -0.43 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:19.683523798
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.13 206.37
# Agg s 206.13
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 13 unreal_pnl -0.40 real_pnl -0.11 ave_price 206.40
# index 2019-09-03 09:38:19.688978297
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.1 206.37
# Agg s 206.1
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 12 unreal_pnl -0.36 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:19.699311853
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.18 206.39
# index 2019-09-03 09:38:19.750998586
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.26 206.39
# index 2019-09-03 09:38:19.942708135
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.22 206.37
# Agg s 206.22
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 11 unreal_pnl -0.33 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:19.975087646
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.19 206.37
# Agg s 206.19
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 10 unreal_pnl -0.30 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:19.975425019
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.16 206.37
# Agg s 206.16
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 9 unreal_pnl -0.27 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:19.975456881
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.13 206.37
# Agg s 206.13
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 8 unreal_pnl -0.24 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:20.183942943
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.11 206.37
# Agg s 206.11
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position 7 unreal_pnl -0.21 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:20.289024878
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.09 206.36
# Agg s 206.09
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.36
# position 6 unreal_pnl -0.24 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:20.289025558
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.07 206.36
# Agg s 206.07
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.36
# position 5 unreal_pnl -0.20 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:20.289029110
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.05 206.36
# Agg s 206.05
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.36
# position 4 unreal_pnl -0.16 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:20.289330823
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.43 206.4 206.04 206.36
# Agg s 206.04
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.36
# position 3 unreal_pnl -0.12 real_pnl -0.12 ave_price 206.40
# index 2019-09-03 09:38:20.289656215
# index 2019-09-03 09:38:20.980230990
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.07 206.362
# index 2019-09-03 09:38:21.153525198
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.04 206.35
# Agg s 206.04
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.35
# position 2 unreal_pnl -0.10 real_pnl -0.17 ave_price 206.40
# index 2019-09-03 09:38:21.153709166
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.02 206.35
# Agg s 206.02
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.35
# position 1 unreal_pnl -0.05 real_pnl -0.22 ave_price 206.40
# index 2019-09-03 09:38:21.153712130
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.01 206.35
# Agg s 206.01
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.35
# position 0 unreal_pnl 0.00 real_pnl -0.27 ave_price 0.00
# index 2019-09-03 09:38:21.153863950
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 205.99 206.35
# Agg s 205.99
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.35
# position -1 unreal_pnl -0.00 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:21.154059621
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 205.97 206.35
# Agg s 205.97
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.35
# position -2 unreal_pnl -0.00 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:21.154084427
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 205.96 206.35
# Agg s 205.96
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.35
# position -3 unreal_pnl -0.00 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:21.154428870
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 205.95 206.35
# Agg s 205.95
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.35
# position -4 unreal_pnl -0.00 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:21.158315503
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 205.94 206.34
# Agg s 205.94
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.34
# position -5 unreal_pnl 0.05 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:21.158680568
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 205.93 206.34
# Agg s 205.93
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.34
# position -6 unreal_pnl 0.06 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:21.210742144
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.02 206.3699
# index 2019-09-03 09:38:21.245505864
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.1 206.37
# index 2019-09-03 09:38:21.602673253
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.08 206.33
# Agg s 206.08
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.33
# position -7 unreal_pnl 0.14 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:21.970390578
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.15 206.35
# index 2019-09-03 09:38:21.985875132
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.12 206.34799999999998
# Agg s 206.12
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.34799999999998
# position -8 unreal_pnl 0.02 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:22.274196045
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.2 206.36
# index 2019-09-03 09:38:22.697867666
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.16 206.32
# Agg s 206.16
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.32
# position -9 unreal_pnl 0.27 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:22.744505365
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.23 206.35
# index 2019-09-03 09:38:22.942647047
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.19 206.3461
# Agg s 206.19
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.3461
# position -10 unreal_pnl 0.04 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:23.108080326
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.16 206.32
# Agg s 206.16
# order_side,order_quantity,trade_price,last_price s 1 206.35 206.32
# position -11 unreal_pnl 0.33 real_pnl -0.27 ave_price 206.35
# index 2019-09-03 09:38:23.628162444
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.23 206.36
# index 2019-09-03 09:38:23.628252207
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.29 206.36
# index 2019-09-03 09:38:23.628274326
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.35 206.36
# index 2019-09-03 09:38:23.628965517
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.4 206.37
# Agg b 206.4
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.37
# position -10 unreal_pnl -0.20 real_pnl -0.25 ave_price 206.35
# index 2019-09-03 09:38:23.628973512
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.45 206.37
# Agg b 206.45
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.37
# position -9 unreal_pnl -0.18 real_pnl -0.23 ave_price 206.35
# index 2019-09-03 09:38:24.089265289
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.49 206.4083
# Agg b 206.49
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.4083
# position -8 unreal_pnl -0.47 real_pnl -0.21 ave_price 206.35
# index 2019-09-03 09:38:24.089706834
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.53 206.41
# Agg b 206.53
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.41
# position -7 unreal_pnl -0.42 real_pnl -0.19 ave_price 206.35
# index 2019-09-03 09:38:24.312728997
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.56 206.44
# Agg b 206.56
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.44
# position -6 unreal_pnl -0.54 real_pnl -0.17 ave_price 206.35
# index 2019-09-03 09:38:24.312801405
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.59 206.44
# Agg b 206.59
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.44
# position -5 unreal_pnl -0.45 real_pnl -0.15 ave_price 206.35
# index 2019-09-03 09:38:24.312863904
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.62 206.44
# Agg b 206.62
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.44
# position -4 unreal_pnl -0.36 real_pnl -0.13 ave_price 206.35
# index 2019-09-03 09:38:24.312923923
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.65 206.44
# Agg b 206.65
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.44
# position -3 unreal_pnl -0.27 real_pnl -0.11 ave_price 206.35
# index 2019-09-03 09:38:24.313121141
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.67 206.44
# Agg b 206.67
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.44
# position -2 unreal_pnl -0.18 real_pnl -0.09 ave_price 206.35
# index 2019-09-03 09:38:24.313180307
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.69 206.44
# Agg b 206.69
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.44
# position -1 unreal_pnl -0.09 real_pnl -0.07 ave_price 206.35
# index 2019-09-03 09:38:24.344149997
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.37 206.35 206.71 206.45
# Agg b 206.71
# order_side,order_quantity,trade_price,last_price b 1 206.37 206.45
# position 0 unreal_pnl 0.00 real_pnl -0.09 ave_price 0.00
# index 2019-09-03 09:38:24.527651735
# index 2019-09-03 09:38:24.528459334
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.43 206.81 206.45
# Agg b 206.81
# order_side,order_quantity,trade_price,last_price b 1 206.45 206.45
# position 1 unreal_pnl 0.00 real_pnl -0.09 ave_price 206.45
# index 2019-09-03 09:38:24.528603530
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.43 206.82 206.45
# Agg b 206.82
# order_side,order_quantity,trade_price,last_price b 1 206.45 206.45
# position 2 unreal_pnl 0.00 real_pnl -0.09 ave_price 206.45
# index 2019-09-03 09:38:24.528632459
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.45 206.43 206.74 206.44
# index 2019-09-03 09:38:24.528706052
# index 2019-09-03 09:38:24.528752116
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.78 206.45
# Agg b 206.78
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.45
# position 3 unreal_pnl -0.02 real_pnl -0.09 ave_price 206.46
# index 2019-09-03 09:38:24.528843799
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.8 206.46
# Agg b 206.8
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.46
# position 4 unreal_pnl 0.00 real_pnl -0.09 ave_price 206.46
# index 2019-09-03 09:38:24.558798634
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.82 206.47
# Agg b 206.82
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.47
# position 5 unreal_pnl 0.04 real_pnl -0.09 ave_price 206.46
# index 2019-09-03 09:38:24.559054006
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.83 206.47
# Agg b 206.83
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.47
# position 6 unreal_pnl 0.04 real_pnl -0.09 ave_price 206.46
# index 2019-09-03 09:38:24.560005573
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.85 206.48
# Agg b 206.85
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.48
# position 7 unreal_pnl 0.11 real_pnl -0.09 ave_price 206.46
# index 2019-09-03 09:38:24.609217437
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.86 206.48
# Agg b 206.86
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.48
# position 8 unreal_pnl 0.12 real_pnl -0.09 ave_price 206.47
# index 2019-09-03 09:38:24.766938688
# index 2019-09-03 09:38:24.766965518
# index 2019-09-03 09:38:24.767137997
# index 2019-09-03 09:38:24.768156677
# index 2019-09-03 09:38:24.790293701
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.89 206.48
# Agg b 206.89
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.48
# position 9 unreal_pnl 0.10 real_pnl -0.09 ave_price 206.47
# index 2019-09-03 09:38:24.790361376
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.9 206.48
# Agg b 206.9
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.48
# position 10 unreal_pnl 0.08 real_pnl -0.09 ave_price 206.47
# index 2019-09-03 09:38:24.798426470
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.91 206.49
# Agg b 206.91
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.49
# position 11 unreal_pnl 0.17 real_pnl -0.09 ave_price 206.47
# index 2019-09-03 09:38:24.800105033
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.92 206.4995
# Agg b 206.92
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.4995
# position 12 unreal_pnl 0.27 real_pnl -0.09 ave_price 206.48
# index 2019-09-03 09:38:24.801226055
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.83 206.49
# index 2019-09-03 09:38:24.879072032
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.85 206.5002
# Agg b 206.85
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.5002
# position 13 unreal_pnl 0.28 real_pnl -0.09 ave_price 206.48
# index 2019-09-03 09:38:24.884261175
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.76 206.48
# index 2019-09-03 09:38:24.884726557
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.68 206.48
# index 2019-09-03 09:38:24.884728049
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.62 206.48
# index 2019-09-03 09:38:24.886035070
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.65 206.5
# Agg b 206.65
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.5
# position 14 unreal_pnl 0.28 real_pnl -0.09 ave_price 206.48
# index 2019-09-03 09:38:24.890937173
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.59 206.49
# index 2019-09-03 09:38:24.891482897
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.63 206.5095
# Agg b 206.63
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.5095
# position 15 unreal_pnl 0.42 real_pnl -0.09 ave_price 206.48
# index 2019-09-03 09:38:24.913843702
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.56 206.48
# index 2019-09-03 09:38:24.914287299
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.5 206.46
# index 2019-09-03 09:38:24.922912156
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.55 206.48
# Agg b 206.55
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.48
# position 16 unreal_pnl -0.04 real_pnl -0.09 ave_price 206.48
# index 2019-09-03 09:38:24.922998424
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.6 206.48
# Agg b 206.6
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.48
# position 17 unreal_pnl -0.06 real_pnl -0.09 ave_price 206.48
# index 2019-09-03 09:38:24.923001692
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.63 206.48
# Agg b 206.63
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.48
# position 18 unreal_pnl -0.08 real_pnl -0.09 ave_price 206.48
# index 2019-09-03 09:38:24.923004421
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.57 206.46
# index 2019-09-03 09:38:24.923210872
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.61 206.48
# Agg b 206.61
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.48
# position 19 unreal_pnl -0.10 real_pnl -0.09 ave_price 206.49
# index 2019-09-03 09:38:24.923386752
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.65 206.48
# Agg b 206.65
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.48
# position 20 unreal_pnl -0.12 real_pnl -0.09 ave_price 206.49
# index 2019-09-03 09:38:24.961626751
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.68 206.49
# Agg b 206.68
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.49
# position 21 unreal_pnl 0.07 real_pnl -0.09 ave_price 206.49
# index 2019-09-03 09:38:24.966732160
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.71 206.50900000000001
# Agg b 206.71
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.50900000000001
# position 22 unreal_pnl 0.48 real_pnl -0.09 ave_price 206.49
# index 2019-09-03 09:38:25.300934926
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.74 206.51
# Agg b 206.74
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.51
# position 23 unreal_pnl 0.51 real_pnl -0.09 ave_price 206.49
# index 2019-09-03 09:38:25.391817574
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.67 206.46
# index 2019-09-03 09:38:25.538820556
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.7 206.4996
# Agg b 206.7
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.4996
# position 24 unreal_pnl 0.27 real_pnl -0.09 ave_price 206.49
# index 2019-09-03 09:38:25.539875063
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.73 206.5
# Agg b 206.73
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.5
# position 25 unreal_pnl 0.28 real_pnl -0.09 ave_price 206.49
# index 2019-09-03 09:38:25.599625061
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.76 206.51
# Agg b 206.76
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.51
# position 26 unreal_pnl 0.54 real_pnl -0.09 ave_price 206.49
# index 2019-09-03 09:38:25.920850338
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.68 206.5
# index 2019-09-03 09:38:25.923232472
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.61 206.5
# index 2019-09-03 09:38:26.097079879
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.55 206.48
# index 2019-09-03 09:38:26.097340647
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.49 206.48
# Pas s
# live order in
# live_order_price,last_price 206.49 206.48
# order side, success s 0
# index 2019-09-03 09:38:26.097417435
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.44 206.48
# Agg s 206.44
# order_side,order_quantity,trade_price,last_price s 1 206.46 206.48
# position 25 unreal_pnl -0.23 real_pnl -0.12 ave_price 206.49
# index 2019-09-03 09:38:26.099501351
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.39 206.46
# Agg s 206.39
# order_side,order_quantity,trade_price,last_price s 1 206.46 206.46
# position 24 unreal_pnl -0.70 real_pnl -0.15 ave_price 206.49
# index 2019-09-03 09:38:26.099505643
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.35 206.46
# Agg s 206.35
# order_side,order_quantity,trade_price,last_price s 1 206.46 206.46
# position 23 unreal_pnl -0.67 real_pnl -0.18 ave_price 206.49
# index 2019-09-03 09:38:26.100114574
# index 2019-09-03 09:38:26.609300910
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.39 206.468
# index 2019-09-03 09:38:26.674440652
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.35 206.45
# Agg s 206.35
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.45
# position 22 unreal_pnl -0.86 real_pnl -0.22 ave_price 206.49
# index 2019-09-03 09:38:26.674540012
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.31 206.45
# Agg s 206.31
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.45
# position 21 unreal_pnl -0.82 real_pnl -0.26 ave_price 206.49
# index 2019-09-03 09:38:26.674602015
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.27 206.45
# Agg s 206.27
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.45
# position 20 unreal_pnl -0.78 real_pnl -0.30 ave_price 206.49
# index 2019-09-03 09:38:26.676223344
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.24 206.44
# Agg s 206.24
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.44
# position 19 unreal_pnl -0.94 real_pnl -0.33 ave_price 206.49
# index 2019-09-03 09:38:26.676227343
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.21 206.44
# Agg s 206.21
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.44
# position 18 unreal_pnl -0.89 real_pnl -0.37 ave_price 206.49
# index 2019-09-03 09:38:26.676231306
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.18 206.44
# Agg s 206.18
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.44
# position 17 unreal_pnl -0.84 real_pnl -0.41 ave_price 206.49
# index 2019-09-03 09:38:26.676372221
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.16 206.44
# Agg s 206.16
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.44
# position 16 unreal_pnl -0.79 real_pnl -0.45 ave_price 206.49
# index 2019-09-03 09:38:26.676575926
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.14 206.44
# Agg s 206.14
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.44
# position 15 unreal_pnl -0.74 real_pnl -0.49 ave_price 206.49
# index 2019-09-03 09:38:26.676577256
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.45 206.12 206.44
# Agg s 206.12
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.44
# position 14 unreal_pnl -0.69 real_pnl -0.53 ave_price 206.49
# index 2019-09-03 09:38:26.676596408
# index 2019-09-03 09:38:26.676610055
# index 2019-09-03 09:38:26.938528769
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.09 206.4358
# Agg s 206.09
# order_side,order_quantity,trade_price,last_price s 1 206.44 206.4358
# position 13 unreal_pnl -0.69 real_pnl -0.58 ave_price 206.49
# index 2019-09-03 09:38:26.952419502
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.17 206.46
# index 2019-09-03 09:38:26.952470085
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.25 206.46
# index 2019-09-03 09:38:26.952606885
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.32 206.46
# index 2019-09-03 09:38:26.952674569
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.38 206.46
# index 2019-09-03 09:38:26.952714487
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.44 206.46
# index 2019-09-03 09:38:26.952746856
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.49 206.46
# Agg b 206.49
# order_side,order_quantity,trade_price,last_price b 1 206.45 206.46
# position 14 unreal_pnl -0.37 real_pnl -0.58 ave_price 206.49
# index 2019-09-03 09:38:26.952758103
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.53 206.46
# Agg b 206.53
# order_side,order_quantity,trade_price,last_price b 1 206.45 206.46
# position 15 unreal_pnl -0.36 real_pnl -0.58 ave_price 206.48
# index 2019-09-03 09:38:26.952767166
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.58 206.47
# Agg b 206.58
# order_side,order_quantity,trade_price,last_price b 1 206.45 206.47
# position 16 unreal_pnl -0.19 real_pnl -0.58 ave_price 206.48
# index 2019-09-03 09:38:26.952887368
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.61 206.47
# Agg b 206.61
# order_side,order_quantity,trade_price,last_price b 1 206.45 206.47
# position 17 unreal_pnl -0.17 real_pnl -0.58 ave_price 206.48
# index 2019-09-03 09:38:26.953596283
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.45 206.44 206.65 206.48
# Agg b 206.65
# order_side,order_quantity,trade_price,last_price b 1 206.45 206.48
# position 18 unreal_pnl 0.03 real_pnl -0.58 ave_price 206.48
# index 2019-09-03 09:38:26.954203611
# index 2019-09-03 09:38:26.954285293
# index 2019-09-03 09:38:26.954439097
# index 2019-09-03 09:38:26.954442530
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.71 206.49
# Agg b 206.71
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.49
# position 19 unreal_pnl 0.20 real_pnl -0.58 ave_price 206.48
# index 2019-09-03 09:38:26.986660405
# index 2019-09-03 09:38:27.012462477
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.64 206.488
# index 2019-09-03 09:38:27.578765560
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.58 206.486
# index 2019-09-03 09:38:27.580337331
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.52 206.4753
# index 2019-09-03 09:38:27.700400883
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.56 206.4866
# Agg b 206.56
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.4866
# position 20 unreal_pnl 0.12 real_pnl -0.58 ave_price 206.48
# index 2019-09-03 09:38:28.679837822
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.5 206.4705
# index 2019-09-03 09:38:28.842544945
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.45 206.43
# Agg s 206.45
# order_side,order_quantity,trade_price,last_price s 1 206.46 206.43
# position 19 unreal_pnl -0.96 real_pnl -0.60 ave_price 206.48
# index 2019-09-03 09:38:28.892249077
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.46 206.5 206.475
# Pas b
# index 2019-09-03 09:38:29.179401213
# live order in
# live_order_price,last_price 206.5 206.43099999999998
# order side, success b 1
# order_side,order_quantity,live_order_price,last_price b 1 206.5 206.43099999999998
# position 20 unreal_pnl -1.01 real_pnl -0.60 ave_price 206.48
# index 2019-09-03 09:38:29.213319234
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.42 206.43099999999998
# Agg s 206.42
# order_side,order_quantity,trade_price,last_price s 1 206.43 206.43099999999998
# position 19 unreal_pnl -0.96 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:30.115581373
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.48 206.47
# Agg b 206.48
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.47
# position 20 unreal_pnl -0.22 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:30.282450462
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.52 206.48
# Agg b 206.52
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.48
# position 21 unreal_pnl -0.01 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:30.282593113
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.57 206.48
# Agg b 206.57
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.48
# position 22 unreal_pnl 0.00 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:30.296626214
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.61 206.5
# Agg b 206.61
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.5
# position 23 unreal_pnl 0.47 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:30.498932931
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.54 206.47
# index 2019-09-03 09:38:30.807016363
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.58 206.48
# Agg b 206.58
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.48
# position 24 unreal_pnl 0.02 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:30.807419885
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.62 206.48
# Agg b 206.62
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.48
# position 25 unreal_pnl 0.03 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:30.810697576
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.65 206.484
# Agg b 206.65
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.484
# position 26 unreal_pnl 0.15 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:30.811327886
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.43 206.69 206.484
# Agg b 206.69
# order_side,order_quantity,trade_price,last_price b 1 206.47 206.484
# position 27 unreal_pnl 0.16 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:31.335539372
# index 2019-09-03 09:38:31.778959967
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.75 206.49
# Agg b 206.75
# order_side,order_quantity,trade_price,last_price b 1 206.51 206.49
# position 28 unreal_pnl 0.30 real_pnl -0.65 ave_price 206.48
# index 2019-09-03 09:38:31.828838019
# index 2019-09-03 09:38:31.972381293
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.68 206.47
# index 2019-09-03 09:38:31.972385165
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.61 206.47
# index 2019-09-03 09:38:31.972389374
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.55 206.47
# index 2019-09-03 09:38:31.980857186
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.49 206.47
# Pas s
# live order in
# live_order_price,last_price 206.49 206.44
# order side, success s 0
# index 2019-09-03 09:38:32.553201614
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.44 206.44
# Agg s 206.44
# order_side,order_quantity,trade_price,last_price s 1 206.47 206.44
# position 27 unreal_pnl -1.06 real_pnl -0.66 ave_price 206.48
# index 2019-09-03 09:38:32.553553070
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.4 206.44
# Agg s 206.4
# order_side,order_quantity,trade_price,last_price s 1 206.47 206.44
# position 26 unreal_pnl -1.02 real_pnl -0.67 ave_price 206.48
# index 2019-09-03 09:38:32.553651976
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.35 206.44
# Agg s 206.35
# order_side,order_quantity,trade_price,last_price s 1 206.47 206.44
# position 25 unreal_pnl -0.98 real_pnl -0.68 ave_price 206.48
# index 2019-09-03 09:38:32.553725569
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.32 206.44
# Agg s 206.32
# order_side,order_quantity,trade_price,last_price s 1 206.47 206.44
# position 24 unreal_pnl -0.94 real_pnl -0.69 ave_price 206.48
# index 2019-09-03 09:38:32.553729460
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.28 206.44
# Agg s 206.28
# order_side,order_quantity,trade_price,last_price s 1 206.47 206.44
# position 23 unreal_pnl -0.90 real_pnl -0.70 ave_price 206.48
# index 2019-09-03 09:38:32.553821074
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.25 206.44
# Agg s 206.25
# order_side,order_quantity,trade_price,last_price s 1 206.47 206.44
# position 22 unreal_pnl -0.86 real_pnl -0.71 ave_price 206.48
# index 2019-09-03 09:38:32.560343018
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.51 206.47 206.33 206.45
# index 2019-09-03 09:38:32.561458377
# index 2019-09-03 09:38:32.561519500
# index 2019-09-03 09:38:32.561589635
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.44 206.36 206.47
# index 2019-09-03 09:38:32.565987560
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.44 206.32 206.44
# Agg s 206.32
# order_side,order_quantity,trade_price,last_price s 1 206.44 206.44
# position 21 unreal_pnl -0.82 real_pnl -0.75 ave_price 206.48
# index 2019-09-03 09:38:32.566023296
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.44 206.28 206.44
# Agg s 206.28
# order_side,order_quantity,trade_price,last_price s 1 206.44 206.44
# position 20 unreal_pnl -0.78 real_pnl -0.79 ave_price 206.48
# index 2019-09-03 09:38:32.566264300
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.44 206.24 206.44
# Agg s 206.24
# order_side,order_quantity,trade_price,last_price s 1 206.44 206.44
# position 19 unreal_pnl -0.75 real_pnl -0.82 ave_price 206.48
# index 2019-09-03 09:38:32.619950858
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.47 206.44 206.21 206.43
# Agg s 206.21
# order_side,order_quantity,trade_price,last_price s 1 206.44 206.43
# position 18 unreal_pnl -0.89 real_pnl -0.86 ave_price 206.48
# index 2019-09-03 09:38:32.623198404
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.44 206.29 206.47
# index 2019-09-03 09:38:32.642530309
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.47 206.44 206.35 206.47
# index 2019-09-03 09:38:32.872137034
# index 2019-09-03 09:38:33.043818250
# index 2019-09-03 09:38:33.378278276
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.45 206.43 206.47
# index 2019-09-03 09:38:33.484406307
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.45 206.49 206.4954
# Pas b
# live order in
# live_order_price,last_price 206.49 206.4954
# order side, success b 0
# index 2019-09-03 09:38:33.489250106
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.45 206.54 206.4954
# Agg b 206.54
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.4954
# position 19 unreal_pnl 0.29 real_pnl -0.86 ave_price 206.48
# index 2019-09-03 09:38:33.640347819
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.45 206.48 206.48
# Pas s
# live order in
# live_order_price,last_price 206.48 206.49
# order side, success s 1
# order_side,order_quantity,live_order_price,last_price s 1 206.48 206.49
# position 18 unreal_pnl 0.17 real_pnl -0.86 ave_price 206.48
# index 2019-09-03 09:38:33.640828640
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.45 206.53 206.49
# Agg b 206.53
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.49
# position 19 unreal_pnl 0.16 real_pnl -0.86 ave_price 206.48
# index 2019-09-03 09:38:33.942501800
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.5 206.45 206.48 206.45
# Pas s
# live order in
# live_order_price,last_price 206.48 206.505
# order side, success s 1
# order_side,order_quantity,live_order_price,last_price s 1 206.48 206.505
# position 18 unreal_pnl 0.43 real_pnl -0.87 ave_price 206.48
# index 2019-09-03 09:38:33.997408986
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.5 206.45 206.53 206.505
# Agg b 206.53
# order_side,order_quantity,trade_price,last_price b 1 206.5 206.505
# position 19 unreal_pnl 0.43 real_pnl -0.87 ave_price 206.48
# index 2019-09-03 09:38:34.252591757
# index 2019-09-03 09:38:34.472268265
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.49 206.45 206.47 206.454
# Pas s
# index 2019-09-03 09:38:34.601261547
# live order in
# live_order_price,last_price 206.47 206.46
# order side, success s 0
# index 2019-09-03 09:38:34.601972518
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.49 206.45 206.52 206.46
# Agg b 206.52
# order_side,order_quantity,trade_price,last_price b 1 206.49 206.46
# position 20 unreal_pnl -0.45 real_pnl -0.87 ave_price 206.48
# index 2019-09-03 09:38:34.927688524
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.49 206.45 206.46 206.45
# Pas s
# live order in
# live_order_price,last_price 206.46 206.45
# order side, success s 0
# index 2019-09-03 09:38:34.927691913
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.49 206.45 206.41 206.45
# Agg s 206.41
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.45
# position 19 unreal_pnl -0.62 real_pnl -0.90 ave_price 206.48
# index 2019-09-03 09:38:34.927795903
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.49 206.45 206.37 206.45
# Agg s 206.37
# order_side,order_quantity,trade_price,last_price s 1 206.45 206.45
# position 18 unreal_pnl -0.59 real_pnl -0.93 ave_price 206.48
# ...
# position -509 unreal_pnl -71.27 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016001169
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.98 206.38
# Agg s 205.98
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.38
# position -510 unreal_pnl -71.25 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016006115
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.97 206.38
# Agg s 205.97
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.38
# position -511 unreal_pnl -71.23 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016166421
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.96 206.38
# Agg s 205.96
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.38
# position -512 unreal_pnl -71.21 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016366142
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.95 206.38
# Agg s 205.95
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.38
# position -513 unreal_pnl -71.19 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016458823
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.94 206.38
# Agg s 205.94
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.38
# position -514 unreal_pnl -71.17 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016696730
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.94 206.37
# Agg s 205.94
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -515 unreal_pnl -66.00 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016777138
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.93 206.37
# Agg s 205.93
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -516 unreal_pnl -65.97 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016806046
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.93 206.37
# Agg s 205.93
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -517 unreal_pnl -65.94 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016818176
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.92 206.37
# Agg s 205.92
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -518 unreal_pnl -65.91 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016821512
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.92 206.37
# Agg s 205.92
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -519 unreal_pnl -65.88 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.016825674
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.91 206.37
# Agg s 205.91
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -520 unreal_pnl -65.85 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.017486744
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.91 206.37
# Agg s 205.91
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -521 unreal_pnl -65.82 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.018859322
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.91 206.37
# Agg s 205.91
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -522 unreal_pnl -65.79 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.018863227
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.9 206.37
# Agg s 205.9
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -523 unreal_pnl -65.76 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.019299175
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.9 206.37
# Agg s 205.9
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -524 unreal_pnl -65.73 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.019944344
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.9 206.37
# Agg s 205.9
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.37
# position -525 unreal_pnl -65.70 real_pnl 34.86 ave_price 206.24
# index 2019-09-03 09:45:05.072794801
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.9 206.3654
# Agg s 205.9
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.3654
# position -526 unreal_pnl -63.25 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.093158794
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.89 206.36
# Agg s 205.89
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.36
# position -527 unreal_pnl -60.37 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.093467671
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.89 206.36
# Agg s 205.89
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.36
# position -528 unreal_pnl -60.33 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.097406843
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.89 206.36
# Agg s 205.89
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.36
# position -529 unreal_pnl -60.29 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.097409764
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.89 206.36
# Agg s 205.89
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.36
# position -530 unreal_pnl -60.25 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.098463664
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.89 206.35
# Agg s 205.89
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.35
# position -531 unreal_pnl -54.90 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.098822099
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.89 206.35
# Agg s 205.89
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.35
# position -532 unreal_pnl -54.85 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.150073318
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.89 206.35
# Agg s 205.89
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.35
# position -533 unreal_pnl -54.80 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.150105121
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.88 206.35
# Agg s 205.88
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.35
# position -534 unreal_pnl -54.75 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.150141184
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.88 206.35
# Agg s 205.88
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.35
# position -535 unreal_pnl -54.70 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.150155271
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.88 206.35
# Agg s 205.88
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.35
# position -536 unreal_pnl -54.65 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.150158495
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.41 206.4 205.88 206.35
# Agg s 205.88
# order_side,order_quantity,trade_price,last_price s 1 206.4 206.35
# position -537 unreal_pnl -54.60 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.523060367
# index 2019-09-03 09:45:05.523091796
# index 2019-09-03 09:45:05.524295991
# index 2019-09-03 09:45:05.531380683
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.36 206.34 205.83 206.3401
# Agg s 205.83
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.3401
# position -538 unreal_pnl -49.28 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.666288134
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.36 206.34 205.93 206.3595
# index 2019-09-03 09:45:05.666368452
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.36 206.34 205.92 206.35
# Agg s 205.92
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.35
# position -539 unreal_pnl -54.62 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.686416882
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.01 206.3595
# index 2019-09-03 09:45:05.686850561
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.36 206.34 205.99 206.35
# Agg s 205.99
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.35
# position -540 unreal_pnl -54.63 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.689878381
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.08 206.3595
# index 2019-09-03 09:45:05.690312213
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.05 206.35
# Agg s 206.05
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.35
# position -541 unreal_pnl -54.64 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:05.929085337
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.03 206.34
# Agg s 206.03
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.34
# position -542 unreal_pnl -49.23 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.000240013
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.11 206.35
# index 2019-09-03 09:45:06.261261344
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.08 206.3483
# Agg s 206.08
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.3483
# position -543 unreal_pnl -53.74 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.268263286
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.16 206.36
# index 2019-09-03 09:45:06.268263375
# index 2019-09-03 09:45:06.268266199
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.23 206.36
# index 2019-09-03 09:45:06.268306652
# index 2019-09-03 09:45:06.268350039
# index 2019-09-03 09:45:06.287443471
# index 2019-09-03 09:45:06.388896204
# index 2019-09-03 09:45:06.912357165
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.19 206.34
# Agg s 206.19
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.34
# position -544 unreal_pnl -49.23 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.912391785
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.15 206.34
# Agg s 206.15
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.34
# position -545 unreal_pnl -49.23 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.912430427
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.36 206.34 206.12 206.34
# Agg s 206.12
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.34
# position -546 unreal_pnl -49.23 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.912431692
# index 2019-09-03 09:45:06.912431877
# index 2019-09-03 09:45:06.913079527
# index 2019-09-03 09:45:06.913364274
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.35 206.34 206.09 206.34
# Agg s 206.09
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.34
# position -547 unreal_pnl -49.23 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.913388376
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.35 206.34 206.06 206.34
# Agg s 206.06
# order_side,order_quantity,trade_price,last_price s 1 206.34 206.34
# position -548 unreal_pnl -49.23 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.913427987
# index 2019-09-03 09:45:06.914450964
# index 2019-09-03 09:45:06.919702659
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.34 206.33 206.03 206.33
# Agg s 206.03
# order_side,order_quantity,trade_price,last_price s 1 206.33 206.33
# position -549 unreal_pnl -43.75 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.920319759
# index 2019-09-03 09:45:06.920324233
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.34 206.33 206.01 206.33
# Agg s 206.01
# order_side,order_quantity,trade_price,last_price s 1 206.33 206.33
# position -550 unreal_pnl -43.75 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.920326271
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.34 206.33 205.99 206.33
# Agg s 205.99
# order_side,order_quantity,trade_price,last_price s 1 206.33 206.33
# position -551 unreal_pnl -43.75 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:06.921664620
# index 2019-09-03 09:45:06.921736896
# index 2019-09-03 09:45:06.930332896
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.34 206.32 205.97 206.32
# Agg s 205.97
# order_side,order_quantity,trade_price,last_price s 1 206.32 206.32
# position -552 unreal_pnl -38.24 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:07.287642619
# index 2019-09-03 09:45:07.287680899
# index 2019-09-03 09:45:07.287701736
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.33 206.31 205.94 206.31
# Agg s 205.94
# order_side,order_quantity,trade_price,last_price s 1 206.31 206.31
# position -553 unreal_pnl -32.72 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:07.287779069
# index 2019-09-03 09:45:07.288137788
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.33 206.31 205.93 206.31
# Agg s 205.93
# order_side,order_quantity,trade_price,last_price s 1 206.31 206.31
# position -554 unreal_pnl -32.72 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:07.288290785
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.33 206.31 205.91 206.31
# Agg s 205.91
# order_side,order_quantity,trade_price,last_price s 1 206.31 206.31
# position -555 unreal_pnl -32.72 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:07.292036049
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.33 206.31 205.9 206.2908
# Agg s 205.9
# order_side,order_quantity,trade_price,last_price s 1 206.31 206.2908
# position -556 unreal_pnl -22.04 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:07.351713069
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.33 206.31 205.99 206.31
# index 2019-09-03 09:45:07.399327145
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.33 206.31 205.97 206.3
# Agg s 205.97
# order_side,order_quantity,trade_price,last_price s 1 206.31 206.3
# position -557 unreal_pnl -27.15 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:07.456169649
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.33 206.31 205.96 206.29
# Agg s 205.96
# order_side,order_quantity,trade_price,last_price s 1 206.31 206.29
# position -558 unreal_pnl -21.56 real_pnl 34.86 ave_price 206.25
# index 2019-09-03 09:45:07.941686144
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.33 206.31 206.04 206.31
# index 2019-09-03 09:45:07.941875463
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.33 206.31 206.12 206.31
# index 2019-09-03 09:45:07.941895553
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.33 206.31 206.19 206.31
# index 2019-09-03 09:45:07.942088231
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.33 206.31 206.25 206.31
# index 2019-09-03 09:45:07.942091863
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.33 206.31 206.31 206.31
# index 2019-09-03 09:45:07.942129111
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.33 206.31 206.36 206.31
# Agg b 206.36
# order_side,order_quantity,trade_price,last_price b 1 206.33 206.31
# position -557 unreal_pnl -32.66 real_pnl 34.93 ave_price 206.25
# index 2019-09-03 09:45:07.942383462
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.33 206.31 206.41 206.32
# Agg b 206.41
# order_side,order_quantity,trade_price,last_price b 1 206.33 206.32
# position -556 unreal_pnl -38.16 real_pnl 35.01 ave_price 206.25
# index 2019-09-03 09:45:07.943080399
# tick -1.0 s
# ask_price,bid_price,fair_value,last_price 206.33 206.31 206.35 206.31
# index 2019-09-03 09:45:07.943090431
# tick 1.0 b
# ask_price,bid_price,fair_value,last_price 206.33 206.31 206.39 206.32
# Agg b 206.39
# order_side,order_quantity,trade_price,last_price b 1 206.33 206.32
# position -555 unreal_pnl -38.09 real_pnl 35.09 ave_price 206.25
# 2019-10-30 21:57:33:161028: end simulation loop
# 2019-10-30 21:57:33:161122: order analytics
# 2019-10-30 21:57:33:187152: Algo run complete.

# %%
results1['midpoints'].plot()
results1['fair_values'].plot()

# %%
trades = results1['trades']
trades.loc[trades['trade_type']=='Pas']
# Out:
#                               trade_px last_price  fair_value ave_price  \
# 2019-09-03 09:38:16.858990497  206.385    206.385      206.37   206.385
# 2019-09-03 09:38:17.292602798  206.375    206.375      206.36    206.38
# 2019-09-03 09:38:17.311745652  206.375    206.375     206.356   206.378
# 2019-09-03 09:38:17.694703453  206.375    206.375      206.37   206.377
# 2019-09-03 09:38:17.694812236  206.375    206.375      206.37   206.377
# 2019-09-03 09:38:17.695099284  206.375    206.375      206.37   206.377
# 2019-09-03 09:38:17.695330214  206.375    206.375      206.37   206.376
# 2019-09-03 09:38:17.695935408  206.375    206.375      206.37   206.376
# 2019-09-03 09:38:17.702094072  206.375    206.375      206.37   206.376
# 2019-09-03 09:38:17.812922256  206.385    206.385      206.37   206.377
# 2019-09-03 09:38:17.822059828  206.385    206.385      206.41   206.377
# 2019-09-03 09:38:17.880092228  206.385    206.385       206.4   206.377
# 2019-09-03 09:38:17.880526047  206.385    206.385      206.39   206.377
# 2019-09-03 09:38:17.981864396  206.385    206.415      206.41   206.377
# 2019-09-03 09:38:17.981876964  206.415    206.415      206.41   206.382
# 2019-09-03 09:38:17.981951926  206.415    206.415      206.41   206.387
# 2019-09-03 09:38:17.983169777  206.415    206.415      206.41    206.39
# 2019-09-03 09:38:18.296386259  206.415    206.415     206.415   206.392
# 2019-09-03 09:38:19.750998586  206.415    206.415      206.39   206.394
# 2019-09-03 09:38:19.942708135  206.415    206.415      206.37   206.396
# 2019-09-03 09:38:21.153525198   206.36     206.36      206.35   206.393
# 2019-09-03 09:38:21.210742144   206.36     206.36      206.37   206.393
# 2019-09-03 09:38:21.602673253   206.36     206.36      206.33   206.391
# 2019-09-03 09:38:21.985875132   206.36     206.36     206.348   206.388
# 2019-09-03 09:38:22.274196045   206.36     206.36      206.36   206.388
# 2019-09-03 09:38:22.697867666   206.36     206.36      206.32   206.386
# 2019-09-03 09:38:22.942647047   206.36     206.36     206.346   206.385
# 2019-09-03 09:38:23.628162444   206.36     206.36      206.36   206.385
# 2019-09-03 09:38:23.628252207   206.36     206.36      206.36   206.383
# 2019-09-03 09:38:23.628274326   206.36     206.36      206.36   206.382
# ...                                ...        ...         ...       ...
# 2019-09-03 09:45:01.612310663  206.435    206.435      206.44   206.307
# 2019-09-03 09:45:01.860033706  206.435    206.435      206.44   206.307
# 2019-09-03 09:45:01.913952225  206.435    206.435      206.43    206.31
# 2019-09-03 09:45:02.020820196   206.44     206.44      206.41   206.312
# 2019-09-03 09:45:02.295205217   206.44     206.44      206.44   206.312
# 2019-09-03 09:45:02.565227820   206.44     206.44     206.424   206.314
# 2019-09-03 09:45:02.765189943   206.42     206.42      206.44   206.314
# 2019-09-03 09:45:02.295205217    7.69437        Pas
# 2019-09-03 09:45:02.565227820    6.71227        Pas
# 2019-09-03 09:45:02.765189943    7.56823        Pas
# 2019-09-03 09:45:03.069221620    7.43619        Pas
# 2019-09-03 09:45:03.191379112    6.73596        Pas
# 2019-09-03 09:45:03.291067095    4.98096        Pas
# 2019-09-03 09:45:03.305059814    4.37596        Pas
# 2019-09-03 09:45:04.869752840    4.48296        Pas
# 2019-09-03 09:45:05.666288134    2.45947        Pas
# 2019-09-03 09:45:05.666368452    1.88947        Pas
# 2019-09-03 09:45:05.686416882    2.42849        Pas
# 2019-09-03 09:45:05.686850561    1.85849        Pas
# 2019-09-03 09:45:05.689878381    2.39802        Pas
# 2019-09-03 09:45:05.690312213    1.82802        Pas
# 2019-09-03 09:45:06.261261344    1.72262        Pas
# 2019-09-03 09:45:06.268263286    2.40854        Pas
# 2019-09-03 09:45:06.912357165    1.17854        Pas
# 2019-09-03 09:45:07.399327145   -1.32146        Pas
# 2019-09-03 09:45:07.941875463   -0.70146        Pas
# 2019-09-03 09:45:07.941895553   -0.71146        Pas
# 2019-09-03 09:45:07.942088231   -0.72146        Pas
# 2019-09-03 09:45:07.942091863   -0.73146        Pas
# 2019-09-03 09:45:07.942129111   -0.74146        Pas
# 2019-09-03 09:45:07.942383462 -0.0614598        Pas
# 2019-09-03 09:45:07.943080399   -0.76146        Pas
# 2019-09-03 09:45:07.943090431 -0.0605818        Pas
#
# [1223 rows x 10 columns]

# %%
trades['trade_px'].plot()
trades[' fair_value'].plot()

# %%
trades['position'].plot()

# %%
(trades['real_pnl']+trades['unreal_pnl']).plot()

# %%
trades['real_pnl'].plot()

# %%
trades['unreal_pnl'].plot()

# %%
results['fair_value'].plot()
results['market_price'].plot()
plt.show()

# %% [markdown]
# ## 2. Output

# %%
statistical_results = tk.trade_statistics( results )

# %%
# P&L Series

intraday_pnl = statistical_results['PNL']
intraday_pnl
# Out:
#                               position unrealized_pnl realized_pnl
# 2019-09-03 09:38:17.244698778        1          -0.01            0
# 2019-09-03 09:38:17.293535447        2          -0.06            0
# 2019-09-03 09:38:17.311745652        1        -0.0337        -0.03
# 2019-09-03 09:38:17.511901738        0             -0        -0.06
# 2019-09-03 09:38:17.596473049       -1           0.02        -0.06
# ...                                ...            ...          ...
# 2019-09-03 09:51:05.611013099      -93       -25.5729        91.55
# 2019-09-03 09:51:05.613221350      -94        -27.889        91.55
# 2019-09-03 09:51:05.614219472      -95       -27.6361        91.55
# 2019-09-03 09:51:05.614281174      -96       -27.3716        91.55
# 2019-09-03 09:51:05.977449655      -97       -27.5301        91.55
#
# [2099 rows x 3 columns]

# %%
# max Long, max Short, Ending Position
# Final, Max, Min P&L

for key in list(statistical_results.keys())[1:]:
    print(key , ':' , statistical_results[key])
# Out:
# max_long_Position : 22
# max_short_Position : -150
# ending_Position : -97
# best_unrealized_PNL : 25.278118336434375
# worst_unrealized_PNL : -27.88900725702871
# total_realized_PNL : 91.54999018074372

# %% [markdown]
# ## 3. Explore Different Calibrations

# %% [markdown]
# ## 4. Risk Adjustment
