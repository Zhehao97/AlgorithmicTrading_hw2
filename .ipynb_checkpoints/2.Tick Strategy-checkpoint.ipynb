# %% [markdown]
# # Tick Strategy
# _Version 0.1_

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# load our helper functios
import simtools as st
import tick as tk
from getstock import *
from simtools import *

matplotlib.rcParams[ 'figure.figsize' ] = ( 16, 9 )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load TAQ Data
#
# We'll assume we have already done some cleaning by using our Tick Data Setup or similar code

# %%
# set up some variables
# NOTE: tickfile is a merged TAQ file!!!
tickfile = '../Data/TSLA-TAQ-aug19v2.zip'
test_day = '08/02/19'
taq = pd.read_pickle(tickfile)

# %%
# filter on date
day = taq[test_day]

# %% [markdown]
# ## Run the Simulator

# %%
# without the tick signal...
results = tk.algo_loop( day )
# Out:
# 2019-10-14 13:39:22:756740: Beginning Tick Strategy run
# 2019-10-14 13:39:22:756933: TODO: remove this message. Simply a test to see how closely you are reading this code
# Average stock spread for sample: 10.2568
# 2019-10-14 13:39:22:990546: starting main loop
# 2019-10-14 13:41:36:645175: end simulation loop
# 2019-10-14 13:41:36:645362: order analytics
# 2019-10-14 13:41:36:743737: Algo run complete.

# %%
results['fair_values'].plot()

# %%
results['midpoints'].plot()
day.trade_px.plot()

# %%
data = results['trades']

# %%
data[pd.notna(data.price)]['shares'].sum()
# Out:
# 0

# %%
results.keys()
# Out:
# dict_keys(['midpoints', 'fair_values', 'tick_factors', 'trades', 'quote_count', 'day_vwap', 'avg_price'])

# %%
results['day_vwap']
# Out:
# 232.61886704507017

# %%
results['avg_price']
# Out:
# 0

# %%
#slippage vs. vwap
results['day_vwap'] - results['avg_price']
# Out:
# 232.61886704507017

# %%
results['trades'].groupby(['trade_type']).count()
# Out:
# Empty DataFrame
# Columns: [price, shares, bar, side]
# Index: []
