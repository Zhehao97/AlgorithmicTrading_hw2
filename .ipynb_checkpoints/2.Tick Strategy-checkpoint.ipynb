# %% [markdown]
# # Tick Strategy
# ### Team: Blue Horseshoe

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# load our helper functios
import simtools as st
import tick as tk
from getstock import *
from simtools import *

matplotlib.rcParams[ 'figure.figsize' ] = ( 16, 9 )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 0. Load TAQ Data
#
# We'll assume we have already done some cleaning by using our Tick Data Setup or similar code

# %%
# set up some variables
# NOTE: tickfile is a merged TAQ file!!!

tickfile = 'TSLA-TAQ-Sep03.zip'

taq = pd.read_pickle(tickfile)

# %%
#test_day = '08/02/19'
#taq[test_day]
taq
# filter on date
# day = taq[test_day]
# Out:
#                               exch  bid_px  bid_size  ask_px  ask_size  \
# 2019-09-03 09:30:00.047754421    C  223.16       2.0  225.17       2.0
# 2019-09-03 09:30:00.101167900  NaN     NaN       NaN     NaN       NaN
# 2019-09-03 09:30:00.101220929    X  211.66       1.0  224.35       1.0
# 2019-09-03 09:30:00.101296213    B  222.66       3.0  225.09       3.0
# 2019-09-03 09:30:00.101477420    X  212.47       1.0  224.35       1.0
# ...                            ...     ...       ...     ...       ...
# 2019-09-03 15:59:59.795231435    V  225.01       3.0    0.00       0.0
# 2019-09-03 15:59:59.797870325    Z  225.01       3.0  225.25       1.0
# 2019-09-03 15:59:59.826747577    P  224.19       2.0  226.00      52.0
# 2019-09-03 15:59:59.830647004    Z  225.01       3.0  225.26       1.0
# 2019-09-03 15:59:59.831028556    P  224.51       1.0  226.00      52.0
#
#                               qu_cond   qu_seqnum  natbbo_ind  qu_cancel  \
# 2019-09-03 09:30:00.047754421       R   1139842.0         0.0        NaN
# 2019-09-03 09:30:00.101167900     NaN         NaN         NaN        NaN
# 2019-09-03 09:30:00.101220929       R   1141112.0         2.0        NaN
# 2019-09-03 09:30:00.101296213       R   1141120.0         0.0        NaN
# 2019-09-03 09:30:00.101477420       R   1141126.0         0.0        NaN
# ...                               ...         ...         ...        ...
# 2019-09-03 15:59:59.795231435       R  50275977.0         0.0        NaN
# 2019-09-03 15:59:59.797870325       R  50276014.0         0.0        NaN
# 2019-09-03 15:59:59.826747577       R  50276892.0         0.0        NaN
# 2019-09-03 15:59:59.830647004       R  50277141.0         0.0        NaN
# 2019-09-03 15:59:59.831028556       R  50277159.0         0.0        NaN
#
#                               qu_source symbol  suffix_x  suffix_y  \
# 2019-09-03 09:30:00.047754421         N   TSLA       NaN       NaN
# 2019-09-03 09:30:00.101167900       NaN   TSLA       NaN       NaN
# 2019-09-03 09:30:00.101220929         N   TSLA       NaN       NaN
# 2019-09-03 09:30:00.101296213         N   TSLA       NaN       NaN
# 2019-09-03 09:30:00.101477420         N   TSLA       NaN       NaN
# ...                                 ...    ...       ...       ...
# 2019-09-03 15:59:59.795231435         N   TSLA       NaN       NaN
# 2019-09-03 15:59:59.797870325         N   TSLA       NaN       NaN
# 2019-09-03 15:59:59.826747577         N   TSLA       NaN       NaN
# 2019-09-03 15:59:59.830647004         N   TSLA       NaN       NaN
# 2019-09-03 15:59:59.831028556         N   TSLA       NaN       NaN
#
#                                trade_size  trade_px
# 2019-09-03 09:30:00.047754421         NaN       NaN
# 2019-09-03 09:30:00.101167900         4.0    224.08
# 2019-09-03 09:30:00.101220929         NaN       NaN
# 2019-09-03 09:30:00.101296213         NaN       NaN
# 2019-09-03 09:30:00.101477420         NaN       NaN
# ...                                   ...       ...
# 2019-09-03 15:59:59.795231435         NaN       NaN
# 2019-09-03 15:59:59.797870325         NaN       NaN
# 2019-09-03 15:59:59.826747577         NaN       NaN
# 2019-09-03 15:59:59.830647004         NaN       NaN
# 2019-09-03 15:59:59.831028556         NaN       NaN
#
# [424664 rows x 15 columns]

# %% [markdown]
# ## 1. Implement the Tick Strategy

# %%
# without the tick signal...
# results = tk.algo_loop( taq )
results = tk.algo_loop( taq )
# Out:
# 2019-10-30 11:39:58:813794: Beginning Tick Strategy run
# Average stock spread for sample: 1.0328
# 2019-10-30 11:39:59:186795: starting main loop

# %%
results
# Out:
#                               tick fair_value market_price trade_price  \
# 2019-09-03 15:38:47.792670447    1    206.105       205.72      205.72
# 2019-09-03 15:38:48.251200675   -1    205.584       205.71      205.71
# 2019-09-03 15:38:51.620451946   -1    205.548      205.715      205.71
# 2019-09-03 15:38:52.112289835   -1    205.527       205.71      205.71
# 2019-09-03 15:38:53.071977388    1    205.732      205.716      205.72
# ...                            ...        ...          ...         ...
# 2019-09-03 15:50:08.596787209   -1    205.915       206.03      206.01
# 2019-09-03 15:50:08.597678589    1     206.11       206.04      206.04
# 2019-09-03 15:50:08.597892938    1     206.14       206.05      206.04
# 2019-09-03 15:50:09.730192288   -1    205.995       206.03      206.03
# 2019-09-03 15:50:10.030352477   -1    205.999       206.03     206.036
#
#                               avg_price position unrealized_pnl realized_pnl  \
# 2019-09-03 15:38:47.792670447    205.72        1              0            0
# 2019-09-03 15:38:48.251200675    205.72        0             -0        -0.01
# 2019-09-03 15:38:51.620451946    205.71       -1         -0.005        -0.01
# 2019-09-03 15:38:52.112289835    205.71       -2             -0        -0.01
# 2019-09-03 15:38:53.071977388    205.71       -1         -0.006            0
# ...                                 ...      ...            ...          ...
# 2019-09-03 15:50:08.596787209   205.912      146        17.2992      20.9854
# 2019-09-03 15:50:08.597678589   205.912      147        18.8636      20.9854
# 2019-09-03 15:50:08.597892938   205.912      148        20.4478      20.9854
# 2019-09-03 15:50:09.730192288   205.912      147        17.3696      21.1036
# 2019-09-03 15:50:10.030352477   205.912      148        17.4644      21.1036
#
#                               trade_shares trade_type trade_side
# 2019-09-03 15:38:47.792670447            1        Agg          b
# 2019-09-03 15:38:48.251200675            1        Agg          s
# 2019-09-03 15:38:51.620451946            1        Agg          s
# 2019-09-03 15:38:52.112289835            1        Agg          s
# 2019-09-03 15:38:53.071977388            1        Agg          b
# ...                                    ...        ...        ...
# 2019-09-03 15:50:08.596787209            1        Agg          s
# 2019-09-03 15:50:08.597678589            1        Agg          b
# 2019-09-03 15:50:08.597892938            1        Agg          b
# 2019-09-03 15:50:09.730192288            1        Agg          s
# 2019-09-03 15:50:10.030352477            1        Pas          b
#
# [1452 rows x 11 columns]

# %%
#results[results['trade_type'] == 'Pas'].tail()

# %%
#results['market_price'].plot(label='market price')
#results['trade_price'].plot(label='trade price')
#results['avg_price'].plot(label='avg price')
results['position'].hist(label='position')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Output

# %%
statistical_results = tk.trade_statistics( results )

# %%
# P&L Series

intraday_pnl = statistical_results['PNL']
intraday_pnl
# Out:
#                               position unrealized_pnl realized_pnl
# 2019-09-03 15:38:47.792670447        1              0            0
# 2019-09-03 15:38:48.251200675        0             -0        -0.01
# 2019-09-03 15:38:51.620451946       -1         -0.005        -0.01
# 2019-09-03 15:38:52.112289835       -2             -0        -0.01
# 2019-09-03 15:38:53.071977388       -1         -0.006            0
# ...                                ...            ...          ...
# 2019-09-03 15:50:08.596787209      146        17.2992      20.9854
# 2019-09-03 15:50:08.597678589      147        18.8636      20.9854
# 2019-09-03 15:50:08.597892938      148        20.4478      20.9854
# 2019-09-03 15:50:09.730192288      147        17.3696      21.1036
# 2019-09-03 15:50:10.030352477      148        17.4644      21.1036
#
# [1452 rows x 3 columns]

# %%
# max Long, max Short, Ending Position
# Final, Max, Min P&L

for key in list(statistical_results.keys())[1:]:
    print(key , ':' , statistical_results[key])
# Out:
# max_long_Position : 166
# max_short_Position : -8
# ending_Position : 148
# best_unrealized_PNL : 28.42397118989993
# worst_unrealized_PNL : -7.651344204401198
# total_realized_PNL : 21.103590481429194

# %% [markdown]
# ## 3. Explore Different Calibrations

# %%
tick_list=[trow-TAQ-1110.zip
trow-TAQ-0513.zip
trow-TAQ-0403.zip
tif-TAQ-11152018.zip
tif-TAQ-05102017.zip
SBUX-TAQ-0815.zip
SBUX-TAQ-0513.zip
SBUX-TAQ-0214.zip
goog-TAQ-Sep27.zip
goog-TAQ-06152017.zip
GOLD-TAQ-10092018.zip
GOLD-TAQ-262017.zip
BLK-TAQ-081117.zip
BLK-TAQ-041017.zip]

# %% [markdown]
# ## 4. Risk Adjustment
